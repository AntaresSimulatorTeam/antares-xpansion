# %% [markdown]
# # Performance history

# %% [markdown]
# This page monitors the evolution of the performance of Antares-Xpansion on several reference studies.

# %% [markdown]
# The following table describes the characteristics of the reference studies :
# - `areas` : number of areas in the study
# - `links` : number of links in the study
# - `master.candidates` : number of investment candidates
# - `master_type` : type of the master problem
# - `subproblems.variables` : number of variables in a single weekly subproblem
# - `subproblems.constraints` : number of constraints in a single weekly subproblem
# - `subproblems.non_zero_coefficients` : number of non-zero coefficients in the matrix of a single weekly subproblem
# - `mc_years` : number of Monte-Carlo years used for the investment study
# - `weeks` : number of weeks considered in each year
# - `resolution.stopping_criterion.type` : stopping criterion type
# - `resolution.stopping_criterion.value` : value of the stopping criterion
#
# The number of subproblems at each iteration is `mc_years` $\times$ `weeks`.

# %%
import json
import pandas as pd
import performance

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
json_file_processor = performance.JsonFileProcessor('perf_data.json')
json_file_processor.run()
json_file_processor.stylize_data_for_display()
# Out:
#                                      areas links master.candidates  \
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246    61   398               112
# 41df0e77-cc24-417c-8772-7bc2b8c40082    61   398               112
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167    61   398               112
# a9af2043-311d-466e-975e-5eb822c4b76f   160   563               325
#
#                                      master.type subproblems.variables  \
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246     integer                197736
# 41df0e77-cc24-417c-8772-7bc2b8c40082     relaxed                197736
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167     relaxed                198072
# a9af2043-311d-466e-975e-5eb822c4b76f     integer                278040
#
#                                      subproblems.constraints  \
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246                   78166
# 41df0e77-cc24-417c-8772-7bc2b8c40082                   78166
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167                   78166
# a9af2043-311d-466e-975e-5eb822c4b76f                   83249
#
#                                      subproblems.non_zero_coefficients  \
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246                           9904028
# 41df0e77-cc24-417c-8772-7bc2b8c40082                           9904028
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167                           9945020
# a9af2043-311d-466e-975e-5eb822c4b76f                          27045279
#
#                                      mc_years weeks  \
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246       10    52
# 41df0e77-cc24-417c-8772-7bc2b8c40082       10    52
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167       10    52
# a9af2043-311d-466e-975e-5eb822c4b76f       10    52
#
#                                      resolution.stopping_criterion.type  \
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246                       relative_gap
# 41df0e77-cc24-417c-8772-7bc2b8c40082                       relative_gap
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167                       absolute_gap
# a9af2043-311d-466e-975e-5eb822c4b76f                       relative_gap
#
#                                      resolution.stopping_criterion.value
# study_id
# d5f1e605-5cb3-4115-ba14-c137ebd45246                            0.000001
# 41df0e77-cc24-417c-8772-7bc2b8c40082                            0.000001
# 9a3dbbab-71c5-4f43-bf8a-695fa3616167                           1000000.0
# a9af2043-311d-466e-975e-5eb822c4b76f                            0.000001

# %% [markdown]
# The graphs show the performance of several versions of Antares-Xpansion on the studies presented above.

# %%
perf_plot_generator = performance.PerfPlotsGenerator(json_file_processor.processed_data)
perf_plot_generator.run()
