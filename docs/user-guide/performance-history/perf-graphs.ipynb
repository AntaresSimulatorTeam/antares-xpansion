# %% [markdown]
# # Performance history

# %% [markdown]
# This page monitors the evolution of the performance of Antares-Xpansion on several reference studies.

# %%
import pandas as pd
import performance

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
perf_data = pd.read_csv('perf_data.csv', index_col=(0,1))
perf_data
# Out:
#                                                     Nb years  Nb weeks  \
# Study name                                 Master
# BP50_M23_EU_CC1_X0_E2_Xpansion_2051_def5   integer        10        52
#                                            integer        10        52
#                                            integer        10        52
#                                            relaxed        10        52
#                                            relaxed        10        52
#                                            relaxed        10        52
# NT2040_Xp_Phase2_12K_withEC_vf3_minFlex_V2 integer        10        52
#                                            integer        10        52
#                                            integer        10        52
#
#                                                     Nb proc  \
# Study name                                 Master
# BP50_M23_EU_CC1_X0_E2_Xpansion_2051_def5   integer       12
# ...

# %%
perf_plot_generator = performance.PerfPlotsGenerator(perf_data)
perf_plot_generator.run()
